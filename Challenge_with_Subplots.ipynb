# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

df = pd.read_csv('/Users/rachellam/Downloads/UN_adult_lit_rate.csv')

# dff = pd.DataFrame()
# dff['rand'] = np.random.rand(100)  # 

# dff['rand_sq'] = dff['rand'] ** 2
# dff['rand_shift'] = dff['rand'] + 2

# # When creating a data frame an index column of counts is created, counting from 0.
# # Here we do a few transforms on that index to create some extra columns.
# dff['counts_sq'] = dff.index ** 2 
# dff['counts_sqrt'] = np.sqrt(dff.index)

# plt.subplot(1, 2, 1)
# plt.plot(dff['rand'], color='purple')
# plt.ylabel('Values')
# plt.title('Random Series')

# plt.subplot(1, 2, 2)
# plt.scatter(x = dff['rand_sq'], y = dff['rand'], color='green')
# plt.ylabel('Squared Values')
# plt.title('Squared Series')


#line graphs

df1 = df.iloc[6:8]
df1 = df1.sort_values(['Year'], axis=0, ascending= True)
Year_a = df1['Year']
Value_a = df1['Value']
plt.subplot(12, 2, 1)
#df1.plot(x='Year', y='Value', kind='bar', legend=False, color='blue') ####
plt.plot(x=Year_a, y=Value_a, color='blue')
plt.title('Algeria Male Lit Rate 15+')

plt.figure(figsize=(10, 5))

df2 = df.iloc[4:6]
df2 = df2.sort_values(['Year'], axis=0, ascending=True)
Year_b = df2['Year']
Value_b = df2['Value']
plt.subplot(12, 2, 2)
#df2.plot(x='Year', y='Value', kind='bar', legend=False, color='pink')
plt.plot(x=Year_b, y=Value_b, color='pink')
plt.title('Algeria Female Lit Rate 15+')


## This shows a fairly dramatic increase in adult literacy rates among both sexes in Algeria between 1987 and 2002.
## The increase could be attributed to improved educational levels, a more stable government, or other factors.

df3 = df.iloc[12:14]
df3 = df3.sort_values(['Year'], axis=0, ascending=True)
Year_c = df3['Year']
Value_c = df3['Value']
plt.subplot(12, 2, 3)
plt.plot(x=Year_c, y=Value_c, legend = False, color='blue')
plt.title('Adult Literacy Rate in Argentina, Male 15+')


df4 = df.iloc[10:12]
df4 = df4.sort_values(['Year'], axis=0, ascending=True)
Year_d = df4['Year']
Value_d = df4['Value']
plt.subplot(12, 2, 4)
plt.plot(x=Year_d, y=Value_d, legend = False, color='pink')
plt.title('Adult Literacy Rate in Argentina, Female 15+')


#scatter plots

plt.subplot(12, 2, 5)
plt.plot(x=Year_a, y=Value_a, kind='scatter', color='blue')
#df1.plot.scatter(x='Year', y='Value', color = 'blue')
plt.title('Adult Literacy Rate in Algeria, Male 15+')

plt.subplot(12, 2, 6)
plt.plot(x=Year_b, y=Value_b, kind='scatter', color='pink')
#df2.plot.scatter(x='Year', y='Value', color = 'pink')
plt.title('Adult Literacy Rate in Algeria, Female 15+')

plt.subplot(12, 2, 7)
plt.plot(x=Year_c, y=Value_c, kind='scatter', color='blue')
#df3.plot.scatter(x='Year', y='Value', color = 'blue')
plt.title('Adult Literacy Rate in Argentina, Male 15+')

plt.subplot(12, 2, 8)
plt.plot(x=Year_d, y=Value_d, kind='scatter',color='pink')
#df4.plot.scatter(x='Year', y='Value', color = 'pink')
plt.title('Adult Literacy Rate in Argentina, Female 15+')


#bar graphs
plt.subplot(12, 2, 9)
plt.plot(x=Year_a, y=Value_a, kind='bar',color='blue')
plt.title('Adult Literacy Rate in Algeria, Male 15+')

plt.subplot(12, 2, 10)
plt.plot(x=Year_b, y=Value_b, kind='bar',color='pink')
plt.title('Adult Literacy Rate in Algeria, Female 15+')

plt.subplot(12, 2, 11)
plt.plot(x=Year_c, y=Value_c, kind='bar',color='blue')
plt.title('Adult Literacy Rate in Argentina, Male 15+')

plt.subplot(12, 2, 12)
plt.plot(x=Year_d, y=Value_d, kind='bar',color='pink')
plt.title('Adult Literacy Rate in Argentina, Female 15+')

plt.show()

## Between 1991 and 2001, there was a much smaller jump in literacy rates in Argentina, since its people were already 
## fairly educated. It seems that educational levels are slow to decrease despite major economic recessions.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('/Users/rachellam/Downloads/UN_adult_lit_rate.csv')
df = df.sort_values('Year', ascending = 'True')

plt.subplot(1, 2, 1)
df1 = df.iloc[6:8]
plt.plot(df1['Year'], df1['Value'], 'bar', 'blue')

plt.subplot(1, 2, 2)
df2 = df.iloc[4:6]
plt.plot(df2['Year'], df2['Value'], 'bar', 'pink')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-b53592e66c65> in <module>()
#       9 plt.subplot(1, 2, 1)
#      10 df1 = df.iloc[6:8]
# ---> 11 plt.plot(df1['Year'], df1['Value'], 'bar', 'blue')
#      12
#      13 plt.subplot(1, 2, 2)
#
# /Users/rachellam/anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3315                       mplDeprecation)
#    3316     try:
# -> 3317         ret = ax.plot(*args, **kwargs)
#    3318     finally:
#    3319         ax._hold = washold
#
# /Users/rachellam/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
# ...
